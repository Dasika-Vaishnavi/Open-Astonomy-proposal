# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasika-Vaishnavi/Open-Astronomy-proposal/blob/main/beautiful_soup_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
# !pip install html5lib

# %%
# !pip install requests

# %%
import requests
url = "https://openastronomy.org/gsoc/gsoc2022/#/projects"
r = requests.get(url)

# %%
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html ng-app="coala">\n    <head>\n\n    <title>Ideas page for Google Summer of Code 2022</title>\n    <link rel="icon" type="image/png" href="https://openastronomy.org/img/logo/logoOA_white_svg.png">\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width initial-scale=1" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="keywords" content="foss, open source, organisations, astronomy,\n    OpenAstronomy, astrophysics, GSoC, projects, members, " />\n    <meta name="description" content="Where all about the combined force of different open source projects in astronomy and astrophysics takes place.\n">\n    <meta name="author" content="OpenAstronomy" />\n    <!-- OGP -->\n    <meta property="og:type" content="website" />\n    <meta property="og:title" content="Ideas page for Google Summer of Code 2022" />\n    <meta property="og:description" content="Where all about the combined force of different open source pro
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.content, 'html5lib')
